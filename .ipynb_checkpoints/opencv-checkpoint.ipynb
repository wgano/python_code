# %% [markdown]
# pip install opencv-python和pip install opencv-contrib-python

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
print(cv2.__version__)
# Out:
# 4.7.0

# %%
img = cv2.imread("./notebook/game.ico")
plt.imshow(img)
#cv2.imshow("outbup",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
cap.set(3,500)
cap.set(4,500)
while True:
    suc,img = cap.read()
    cv2.imshow("yes",img)
    if cv2.waitKey(1)&0xFF==ord('q'):
        break

# %%
grey = cv2.cvtColor(img,cv2.CO)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9404\4053963178.py in <module>
#       1 while True:
# ----> 2     suc,img = cap.read()
#       3     cv2.imshow("yes",img)
#
# KeyboardInterrupt:
