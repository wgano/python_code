# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-6,4,100)
y = x**2+2*x+5
plt.plot(x,y)

# %%
x = 3
alaph = 0.8
itliternum = 40

# %%
for i in range(itliternum):
    x = x-alaph*(2*x+2)

# %%
print(x)
# Out:
# -1.0
